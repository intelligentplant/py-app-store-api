# %% [markdown]
# # Set Up
#
# Here is the standard bit of code that will set up the Intelligent Plant App Store and Data Core API clients for a notebook

# %%
import json

import intelligent_plant.session_manager as session_manager
import intelligent_plant.utility as utility

# Remeber to enable the device code flow in the app store app registration

#load the json config file with the app information
with open('config.json') as json_config_file:
    config = json.load(json_config_file)

    app_id = config['app']['id']
    app_secret = config['app']['secret']
    base_url = config['app_store']['base_url']


app_store = session_manager.load_session_or_login(app_id, app_secret, scopes=['DataRead'], base_url=base_url)

data_core = app_store.get_data_core_client()

# %% [markdown]
# # App Store

# %% [markdown]
# ## Get Data Core Client
#
# The app store client contains a function `get_data_core_client(..)` that instantiates a data core client with the same access information as that app store client. This is used to get the data core client needed to make data queries.

# %%
app_store.get_data_core_client()

# %% [markdown]
# ## Get User Info
#
# The `get_user_info()` function which can be used to get the information of the currently logged in user.

# %%
app_store.get_user_info()
# Out:
# {'ApplicationUserId': '48bafa11-ce56-4bdc-9e5a-088ee1c36f56',
#  'UserId': '48bafa11-ce56-4bdc-9e5a-088ee1c36f56',
#  'FirstName': 'Ross',
#  'LastName': 'Kelso',
#  'FormattedName': 'Ross RK. Kelso',
#  'Industry': None,
#  'Org': 'Intelligent Plant',
#  'LastLogIn': '2024-04-29T10:18:15.117',
#  'PicUrl': 'https://appstore.intelligentplant.com/profilepic/48bafa11-ce56-4bdc-9e5a-088ee1c36f56',
#  'PicETag': None,
#  'InfoAll': None,
#  'VerificationStatus': 'Verified',
#  'CreditBalance': 'NaN',
#  'Email': None,
#  'HasSharedApp': False,
#  'HasSharedAppStore': False}

# %% [markdown]
# # Data Core
#
# To get the data core client object use the `app_store.get_data_core_client()` function.

# %%
data_core = app_store.get_data_core_client()

# %% [markdown]
# **These examples use IP Datasource 2 as the data source please make sure that it is authorized for the Jupyter app**
#
# https://appstore.intelligentplant.com/Security/Apps

# %% [markdown]
# ## Get Data Sources
#
# The get data sources method can be used to query the data sources available to the currently logged in user.
#
# Returns:
# A list of of available data sources and their meta data.
#
# **When making other queries you want to use the fully qualified data source name**
#
# ```python
# datasource["Name"]["QualifiedName"]
# ```

# %%
data_core.get_data_sources()
# Out:
# [{'Host': None,
#   'SupportedFeatures': 'TagSearch, ReadTagValues, WriteTagValues, ValuePushNotifications, AssetModelBrowsing, AnnotationManagement',
#   'Name': {'Name': 'Alarm Analysis Demo',
#    'Namespace': 'FCBB05262EADC0B147746EE6DFB2B3EA5C272C33C2C5E3FE8F473D85529461CA',
#    'QualifiedName': 'FCBB05262EADC0B147746EE6DFB2B3EA5C272C33C2C5E3FE8F473D85529461CA.Alarm Analysis Demo',
#    'DisplayName': 'Alarm Analysis Demo (Demo Data Sources - IPABZAPP0009)',
#    'Aliases': []},
#   'TypeName': 'DataCore.Gestalt.GestaltBridgeDriver',
#   'Description': 'Includes Alarm and Event analysis from varous simulated plant simulations.',
#   'Status': {'RunningStatus': 'Running',
#    'HealthStatus': {'IsHealthy': True, 'Properties': []},
#    'IsInitialised': True,
#    'IsDisabled': False,
#    'DebugMode': False,
#    'UtcStartupTime': '2025-02-10T04:00:32.3207132Z',
#    'UtcLastModified': '2025-02-10T14:31:25.4250918Z',
#    'Uptime': '10:30:53.1043786',
#    'Messages': [],
#    'Properties': [{'Name': 'Data Core Version', 'Value': '3.2.21266+180'},
#     {'Name': 'Driver Version', 'Value': '3.2.21266+180'},
#     {'Name': 'Events Sent', 'Value': '0'},
#     {'Name': 'Events Rejected', 'Value': '0'},
#     {'Name': 'Active Subscriber Count', 'Value': '0'},
#     {'Name': 'Keep-Alive Data Queries', 'Value': 'Disabled'}]},
#   'Settings': [],
#   'Properties': {'Data Core Version': '3.2.21266+180',
#    'Driver Version': '3.2.21266+180',
#    'Events Sent': '0',
#    'Events Rejected': '0',
#    'Active Subscriber Count': '0',
#    'Keep-Alive Data Queries': 'Disabled',
#    'Remote Type': 'DataCore.AlarmAnalysis.AlarmAnalysisDriver'},
#   'AuthorizationRules': []},
#  {'Host': None,
#   'SupportedFeatures': 'TagSearch, ReadTagValues, ValuePushNotifications, AnnotationManagement',
#   'Name': {'Name': 'Oil Co Demo',
#    'Namespace': 'FCBB05262EADC0B147746EE6DFB2B3EA5C272C33C2C5E3FE8F473D85529461CA',
#    'QualifiedName': 'FCBB05262EADC0B147746EE6DFB2B3EA5C272C33C2C5E3FE8F473D85529461CA.Oil Co Demo',
#    'DisplayName': 'Oil Co Demo (Demo Data Sources - IPABZAPP0009)',
#    'Aliases': []},
#   'TypeName': 'DataCore.Gestalt.GestaltBridgeDriver',
#   'Description': 'Demo dataset from an imaginary offshore oil platform, including topside and subsea tags.',
#   'Status': {'RunningStatus': 'Running',
#    'HealthStatus': {'IsHealthy': True, 'Properties': []},
#    'IsInitialised': True,
#    'IsDisabled': False,
#    'DebugMode': False,
#    'UtcStartupTime': '2025-02-10T04:00:32.3363577Z',
#    'UtcLastModified': '2025-02-10T14:31:25.4250918Z',
#    'Uptime': '10:30:53.0887341',
#    'Messages': [],
#    'Properties': [{'Name': 'Data Core Version', 'Value': '3.2.21266+180'},
#     {'Name': 'Driver Version', 'Value': '3.2.21266+180'},
#     {'Name': 'Events Sent', 'Value': '0'},
#     {'Name': 'Events Rejected', 'Value': '0'},
#     {'Name': 'Active Subscriber Count', 'Value': '0'},
#     {'Name': 'Keep-Alive Data Queries', 'Value': 'Disabled'}]},
#   'Settings': [],
#   'Properties': {'Data Core Version': '3.2.21266+180',
#    'Driver Version': '3.2.21266+180',
#    'Events Sent': '0',
#    'Events Rejected': '0',
#    'Active Subscriber Count': '0',
#    'Keep-Alive Data Queries': 'Disabled',
#    'Remote Type': 'DataCore.Csv.CsvDriver'},
#   'AuthorizationRules': []}]

# %%
dsn = 'FCBB05262EADC0B147746EE6DFB2B3EA5C272C33C2C5E3FE8F473D85529461CA.Oil Co Demo'

# %% [markdown]
# ## Get Tags
#
# The `get_tags(..)` function is used to query a data source for the available tags.
#
# A tag is the name and meta data of a single data stream.
#
# Tag searches are paginated to prevent the request sizes from getting too large.
#
# Parameters:
# - `dsn` The fully qualified name of the data source you want to query, see `get_data_sources(..)` for more information
# - `page` (Optional, default = 1) The number of the results page you would like to get
# - `page_size` (Optional, default = 20) The number of results to return per page
# - `filters` (Optional, default = {}) A dictionary of filters to apply where the key is the field name (e.g. name, description, unit) and the value is the filter to apply (which can include the wildcards `?` and `*`)
#
# Wildcards:
# - `?` Any single character
# - `*` Ay number (including 0) of any character
#
# Returns:
# A list of available tag objects
#
# Data source information is the in 'DataSourceName' dictionary.
#
# The tag information is in the 'Tags' list.
#
# **In data queryies you want to use the values of the tag ID field**

# %%
data_core.get_tags(dsn)
# Out:
# [{'Id': 'AT-100143.IND_EU',
#   'Name': 'AT-100143.IND_EU',
#   'Description': '',
#   'UnitOfMeasure': '',
#   'Labels': None,
#   'Properties': {'Is Numeric': {'Name': 'Is Numeric',
#     'Category': 'General',
#     'Description': 'Indicates if the tag contains any numeric values in the CSV data.',
#     'DisplayIndex': 0,
#     'Value': True,
#     'IsReadOnly': True},
#    'Raw Sample Count': {'Name': 'Raw Sample Count',
#     'Category': 'General',
#     'Description': 'The number of raw samples for the tag in the CSV data that was loaded.',
#     'DisplayIndex': 0,
#     'Value': 4320,
#     'IsReadOnly': True},
#    'UTC Earliest Raw Sample Time': {'Name': 'UTC Earliest Raw Sample Time',
#     'Category': 'General',
#     'Description': 'The earliest UTC time stamp in the CSV data that contains values for the tag.',
#     'DisplayIndex': 0,
#     'Value': '2022-01-01T00:00:00Z',
#     'IsReadOnly': True},
#    'UTC Latest Raw Sample Time': {'Name': 'UTC Latest Raw Sample Time',
#     'Category': 'General',
#     'Description': 'The latest UTC time stamp in the CSV data that contains values for the tag.',
#     'DisplayIndex': 0,
#     'Value': None,
#     'IsReadOnly': True},
#    'type': {'Name': 'Tag type',
#     'Category': 'Equipment Properties',
#     'Description': 'Tag (equipment) type.',
#     'DisplayIndex': 0,
#     'Value': 'tag',
#     'IsReadOnly': True},
#    'cats': {'Name': 'Tag cats',
#     'Category': 'Equipment Properties',
#     'Description': 'Tag (equipment) terms.',
#     'DisplayIndex': 0,
#     'Value': 'AT-100143.IND_EU,AT,100143,IND,EU,Transmitter,Analysis',
#     'IsReadOnly': True},
#    'originDsn': {'Name': 'Tag origin dsn',
#     'Category': 'Equipment Properties',
#     'Description': 'Tag (equipment) origin datasource name.',
#     'DisplayIndex': 0,
#     'Value': 'Oil Co Demo',
#     'IsReadOnly': True},
#    'totalTags': {'Name': 'Total tags',
#     'Category': 'Equipment Properties',
#     'Description': 'Total number of tags matching the query term.',
#     'DisplayIndex': 0,
#     'Value': 294.0,
#     'IsReadOnly': True}},
#   'DigitalStates': [],
#   'IsMetaTag': False},
#  {'Id': 'FT-100127-A.PV_IND',
#   'Name': 'FT-100127-A.PV_IND',
#   'Description': '',
#   'UnitOfMeasure': '',
#   'Labels': None,
#   'Properties': {'Is Numeric': {'Name': 'Is Numeric',
#     'Category': 'General',
#     'Description': 'Indicates if the tag contains any numeric values in the CSV data.',
#     'DisplayIndex': 0,
#     'Value': True,
#     'IsReadOnly': True},
#    'Raw Sample Count': {'Name': 'Raw Sample Count',
#     'Category': 'General',
#     'Description': 'The number of raw samples for the tag in the CSV data that was loaded.',
#     'DisplayIndex': 0,
#     'Value': 4320,
#     'IsReadOnly': True},
#    'UTC Earliest Raw Sample Time': {'Name': 'UTC Earliest Raw Sample Time',
#     'Category': 'General',
#     'Description': 'The earliest UTC time stamp in the CSV data that contains values for the tag.',
#     'DisplayIndex': 0,
#     'Value': '2022-01-01T00:00:00Z',
#     'IsReadOnly': True},
#    'UTC Latest Raw Sample Time': {'Name': 'UTC Latest Raw Sample Time',
#     'Category': 'General',
#     'Description': 'The latest UTC time stamp in the CSV data that contains values for the tag.',
#     'DisplayIndex': 0,
#     'Value': None,
#     'IsReadOnly': True},
#    'type': {'Name': 'Tag type',
#     'Category': 'Equipment Properties',
#     'Description': 'Tag (equipment) type.',
#     'DisplayIndex': 0,
#     'Value': 'tag',
#     'IsReadOnly': True},
#    'cats': {'Name': 'Tag cats',
#     'Category': 'Equipment Properties',
#     'Description': 'Tag (equipment) terms.',
#     'DisplayIndex': 0,
#     'Value': 'FT-100127-A.PV_IND,FT,100127-A,100127,A,PV,IND,Transmitter,Flow,Process Variable',
#     'IsReadOnly': True},
#    'originDsn': {'Name': 'Tag origin dsn',
#     'Category': 'Equipment Properties',
#     'Description': 'Tag (equipment) origin datasource name.',
#     'DisplayIndex': 0,
#     'Value': 'Oil Co Demo',
#     'IsReadOnly': True},
#    'totalTags': {'Name': 'Total tags',
#     'Category': 'Equipment Properties',
#     'Description': 'Total number of tags matching the query term.',
#     'DisplayIndex': 0,
#     'Value': 294.0,
#     'IsReadOnly': True}},
#   'DigitalStates': [],
#   'IsMetaTag': False},
#  {'Id': 'FT-100127-B.IND_EU',
#   'Name': 'FT-100127-B.IND_EU',
#   'Description': '',
#   'UnitOfMeasure': '',
#   'Labels': None,
#   'Properties': {'Is Numeric': {'Name': 'Is Numeric',
#     'Category': 'General',
#     'Description': 'Indicates if the tag contains any numeric values in the CSV data.',
#     'DisplayIndex': 0,
#     'Value': True,
#     'IsReadOnly': True},
#    'Raw Sample Count': {'Name': 'Raw Sample Count',
#     'Category': 'General',
#     'Description': 'The number of raw samples for the tag in the CSV data that was loaded.',
#     'DisplayIndex': 0,
#     'Value': 4320,
#     'IsReadOnly': True},
#    'UTC Earliest Raw Sample Time': {'Name': 'UTC Earliest Raw Sample Time',
#     'Category': 'General',
#     'Description': 'The earliest UTC time stamp in the CSV data that contains values for the tag.',
#     'DisplayIndex': 0,
#     'Value': '2022-01-01T00:00:00Z',
#     'IsReadOnly': True},
#    'UTC Latest Raw Sample Time': {'Name': 'UTC Latest Raw Sample Time',
#     'Category': 'General',
#     'Description': 'The latest UTC time stamp in the CSV data that contains values for the tag.',
#     'DisplayIndex': 0,
#     'Value': None,
#     'IsReadOnly': True},
#    'type': {'Name': 'Tag type',
#     'Category': 'Equipment Properties',
#     'Description': 'Tag (equipment) type.',
#     'DisplayIndex': 0,
#     'Value': 'tag',
#     'IsReadOnly': True},
#    'cats': {'Name': 'Tag cats',
#     'Category': 'Equipment Properties',
#     'Description': 'Tag (equipment) terms.',
#     'DisplayIndex': 0,
#     'Value': 'FT-100127-B.IND_EU,FT,100127-B,100127,B,IND,EU,Transmitter,Flow',
#     'IsReadOnly': True},
#    'originDsn': {'Name': 'Tag origin dsn',
#     'Category': 'Equipment Properties',
#     'Description': 'Tag (equipment) origin datasource name.',
#     'DisplayIndex': 0,
#     'Value': 'Oil Co Demo',
#     'IsReadOnly': True},
#    'totalTags': {'Name': 'Total tags',
#     'Category': 'Equipment Properties',
#     'Description': 'Total number of tags matching the query term.',
#     'DisplayIndex': 0,
#     'Value': 294.0,
#     'IsReadOnly': True}},
#   'DigitalStates': [],
#   'IsMetaTag': False},
#  {'Id': 'FT-100132-1',
#   'Name': 'FT-100132-1',
#   'Description': '',
#   'UnitOfMeasure': '',
#   'Labels': None,
#   'Properties': {'Is Numeric': {'Name': 'Is Numeric',
#     'Category': 'General',
#     'Description': 'Indicates if the tag contains any numeric values in the CSV data.',
#     'DisplayIndex': 0,
#     'Value': True,
#     'IsReadOnly': True},
#    'Raw Sample Count': {'Name': 'Raw Sample Count',
#     'Category': 'General',
#     'Description': 'The number of raw samples for the tag in the CSV data that was loaded.',
#     'DisplayIndex': 0,
#     'Value': 4320,
#     'IsReadOnly': True},
#    'UTC Earliest Raw Sample Time': {'Name': 'UTC Earliest Raw Sample Time',
#     'Category': 'General',
#     'Description': 'The earliest UTC time stamp in the CSV data that contains values for the tag.',
#     'DisplayIndex': 0,
#     'Value': '2022-01-01T00:00:00Z',
#     'IsReadOnly': True},
#    'UTC Latest Raw Sample Time': {'Name': 'UTC Latest Raw Sample Time',
#     'Category': 'General',
#     'Description': 'The latest UTC time stamp in the CSV data that contains values for the tag.',
#     'DisplayIndex': 0,
#     'Value': None,
#     'IsReadOnly': True},
#    'type': {'Name': 'Tag type',
#     'Category': 'Equipment Properties',
#     'Description': 'Tag (equipment) type.',
#     'DisplayIndex': 0,
#     'Value': 'tag',
#     'IsReadOnly': True},
#    'cats': {'Name': 'Tag cats',
#     'Category': 'Equipment Properties',
#     'Description': 'Tag (equipment) terms.',
#     'DisplayIndex': 0,
#     'Value': 'FT-100132-1,FT,100132-1,100132,1,Transmitter,Flow',
#     'IsReadOnly': True},
#    'originDsn': {'Name': 'Tag origin dsn',
#     'Category': 'Equipment Properties',
#     'Description': 'Tag (equipment) origin datasource name.',
#     'DisplayIndex': 0,
#     'Value': 'Oil Co Demo',
#     'IsReadOnly': True},
#    'totalTags': {'Name': 'Total tags',
#     'Category': 'Equipment Properties',
#     'Description': 'Total number of tags matching the query term.',
#     'DisplayIndex': 0,
#     'Value': 294.0,
#     'IsReadOnly': True}},
#   'DigitalStates': [],
#   'IsMetaTag': False},
#  {'Id': 'LIC001',
#   'Name': 'LIC001',
#   'Description': 'Level Indicator Controller',
#   'UnitOfMeasure': '',
#   'Labels': None,
#   'Properties': {'Is Numeric': {'Name': 'Is Numeric',
#     'Category': 'General',
#     'Description': 'Indicates if the tag contains any numeric values in the CSV data.',
#     'DisplayIndex': 0,
#     'Value': True,
#     'IsReadOnly': True},
#    'Raw Sample Count': {'Name': 'Raw Sample Count',
#     'Category': 'General',
#     'Description': 'The number of raw samples for the tag in the CSV data that was loaded.',
#     'DisplayIndex': 0,
#     'Value': 4320,
#     'IsReadOnly': True},
#    'UTC Earliest Raw Sample Time': {'Name': 'UTC Earliest Raw Sample Time',
#     'Category': 'General',
#     'Description': 'The earliest UTC time stamp in the CSV data that contains values for the tag.',
#     'DisplayIndex': 0,
#     'Value': '2022-01-01T00:00:00Z',
#     'IsReadOnly': True},
#    'UTC Latest Raw Sample Time': {'Name': 'UTC Latest Raw Sample Time',
#     'Category': 'General',
#     'Description': 'The latest UTC time stamp in the CSV data that contains values for the tag.',
#     'DisplayIndex': 0,
#     'Value': None,
#     'IsReadOnly': True},
#    'type': {'Name': 'Tag type',
#     'Category': 'Equipment Properties',
#     'Description': 'Tag (equipment) type.',
#     'DisplayIndex': 0,
#     'Value': 'tag',
#     'IsReadOnly': True},
#    'cats': {'Name': 'Tag cats',
#     'Category': 'Equipment Properties',
#     'Description': 'Tag (equipment) terms.',
#     'DisplayIndex': 0,
#     'Value': 'LIC001,LIC,001,Level,Indicator,Controller,Indicator controller',
#     'IsReadOnly': True},
#    'originDsn': {'Name': 'Tag origin dsn',
#     'Category': 'Equipment Properties',
#     'Description': 'Tag (equipment) origin datasource name.',
#     'DisplayIndex': 0,
#     'Value': 'Oil Co Demo',
#     'IsReadOnly': True},
#    'totalTags': {'Name': 'Total tags',
#     'Category': 'Equipment Properties',
#     'Description': 'Total number of tags matching the query term.',
#     'DisplayIndex': 0,
#     'Value': 294.0,
#     'IsReadOnly': True}},
#   'DigitalStates': [],
#   'IsMetaTag': False},
#  {'Id': 'LIC001_OP',
#   'Name': 'LIC001_OP',
#   'Description': '',
#   'UnitOfMeasure': '',
#   'Labels': None,
#   'Properties': {'Is Numeric': {'Name': 'Is Numeric',
#     'Category': 'General',
#     'Description': 'Indicates if the tag contains any numeric values in the CSV data.',
#     'DisplayIndex': 0,
#     'Value': True,
#     'IsReadOnly': True},
#    'Raw Sample Count': {'Name': 'Raw Sample Count',
#     'Category': 'General',
#     'Description': 'The number of raw samples for the tag in the CSV data that was loaded.',
#     'DisplayIndex': 0,
#     'Value': 4320,
#     'IsReadOnly': True},
#    'UTC Earliest Raw Sample Time': {'Name': 'UTC Earliest Raw Sample Time',
#     'Category': 'General',
#     'Description': 'The earliest UTC time stamp in the CSV data that contains values for the tag.',
#     'DisplayIndex': 0,
#     'Value': '2022-01-01T00:00:00Z',
#     'IsReadOnly': True},
#    'UTC Latest Raw Sample Time': {'Name': 'UTC Latest Raw Sample Time',
#     'Category': 'General',
#     'Description': 'The latest UTC time stamp in the CSV data that contains values for the tag.',
#     'DisplayIndex': 0,
#     'Value': None,
#     'IsReadOnly': True},
#    'type': {'Name': 'Tag type',
#     'Category': 'Equipment Properties',
#     'Description': 'Tag (equipment) type.',
#     'DisplayIndex': 0,
#     'Value': 'tag',
#     'IsReadOnly': True},
#    'cats': {'Name': 'Tag cats',
#     'Category': 'Equipment Properties',
#     'Description': 'Tag (equipment) terms.',
#     'DisplayIndex': 0,
#     'Value': 'LIC001_OP,LIC,001_OP,LIC001,OP,Indicator controller,Level',
#     'IsReadOnly': True},
#    'originDsn': {'Name': 'Tag origin dsn',
#     'Category': 'Equipment Properties',
#     'Description': 'Tag (equipment) origin datasource name.',
#     'DisplayIndex': 0,
#     'Value': 'Oil Co Demo',
#     'IsReadOnly': True},
#    'totalTags': {'Name': 'Total tags',
#     'Category': 'Equipment Properties',
#     'Description': 'Total number of tags matching the query term.',
#     'DisplayIndex': 0,
#     'Value': 294.0,
#     'IsReadOnly': True}},
#   'DigitalStates': [],
#   'IsMetaTag': False},
#  {'Id': 'LIC001_PV',
#   'Name': 'LIC001_PV',
#   'Description': '',
#   'UnitOfMeasure': '',
#   'Labels': None,
#   'Properties': {'Is Numeric': {'Name': 'Is Numeric',
#     'Category': 'General',
#     'Description': 'Indicates if the tag contains any numeric values in the CSV data.',
#     'DisplayIndex': 0,
#     'Value': True,
#     'IsReadOnly': True},
#    'Raw Sample Count': {'Name': 'Raw Sample Count',
#     'Category': 'General',
#     'Description': 'The number of raw samples for the tag in the CSV data that was loaded.',
#     'DisplayIndex': 0,
#     'Value': 4320,
#     'IsReadOnly': True},
#    'UTC Earliest Raw Sample Time': {'Name': 'UTC Earliest Raw Sample Time',
#     'Category': 'General',
#     'Description': 'The earliest UTC time stamp in the CSV data that contains values for the tag.',
#     'DisplayIndex': 0,
#     'Value': '2022-01-01T00:00:00Z',
#     'IsReadOnly': True},
#    'UTC Latest Raw Sample Time': {'Name': 'UTC Latest Raw Sample Time',
#     'Category': 'General',
#     'Description': 'The latest UTC time stamp in the CSV data that contains values for the tag.',
#     'DisplayIndex': 0,
#     'Value': None,
#     'IsReadOnly': True},
#    'type': {'Name': 'Tag type',
#     'Category': 'Equipment Properties',
#     'Description': 'Tag (equipment) type.',
#     'DisplayIndex': 0,
#     'Value': 'tag',
#     'IsReadOnly': True},
#    'cats': {'Name': 'Tag cats',
#     'Category': 'Equipment Properties',
#     'Description': 'Tag (equipment) terms.',
#     'DisplayIndex': 0,
#     'Value': 'LIC001_PV,LIC,001_PV,LIC001,PV,Indicator controller,Level',
#     'IsReadOnly': True},
#    'originDsn': {'Name': 'Tag origin dsn',
#     'Category': 'Equipment Properties',
#     'Description': 'Tag (equipment) origin datasource name.',
#     'DisplayIndex': 0,
#     'Value': 'Oil Co Demo',
#     'IsReadOnly': True},
#    'totalTags': {'Name': 'Total tags',
#     'Category': 'Equipment Properties',
#     'Description': 'Total number of tags matching the query term.',
#     'DisplayIndex': 0,
#     'Value': 294.0,
#     'IsReadOnly': True}},
#   'DigitalStates': [],
#   'IsMetaTag': False},
#  {'Id': 'LIC001_SP',
#   'Name': 'LIC001_SP',
#   'Description': '',
#   'UnitOfMeasure': '',
#   'Labels': None,
#   'Properties': {'Is Numeric': {'Name': 'Is Numeric',
#     'Category': 'General',
#     'Description': 'Indicates if the tag contains any numeric values in the CSV data.',
#     'DisplayIndex': 0,
#     'Value': True,
#     'IsReadOnly': True},
#    'Raw Sample Count': {'Name': 'Raw Sample Count',
#     'Category': 'General',
#     'Description': 'The number of raw samples for the tag in the CSV data that was loaded.',
#     'DisplayIndex': 0,
#     'Value': 4320,
#     'IsReadOnly': True},
#    'UTC Earliest Raw Sample Time': {'Name': 'UTC Earliest Raw Sample Time',
#     'Category': 'General',
#     'Description': 'The earliest UTC time stamp in the CSV data that contains values for the tag.',
#     'DisplayIndex': 0,
#     'Value': '2022-01-01T00:00:00Z',
#     'IsReadOnly': True},
#    'UTC Latest Raw Sample Time': {'Name': 'UTC Latest Raw Sample Time',
#     'Category': 'General',
#     'Description': 'The latest UTC time stamp in the CSV data that contains values for the tag.',
#     'DisplayIndex': 0,
#     'Value': None,
#     'IsReadOnly': True},
#    'type': {'Name': 'Tag type',
#     'Category': 'Equipment Properties',
#     'Description': 'Tag (equipment) type.',
#     'DisplayIndex': 0,
#     'Value': 'tag',
#     'IsReadOnly': True},
#    'cats': {'Name': 'Tag cats',
#     'Category': 'Equipment Properties',
#     'Description': 'Tag (equipment) terms.',
#     'DisplayIndex': 0,
#     'Value': 'LIC001_SP,LIC,001_SP,LIC001,SP,Indicator controller,Level',
#     'IsReadOnly': True},
#    'originDsn': {'Name': 'Tag origin dsn',
#     'Category': 'Equipment Properties',
#     'Description': 'Tag (equipment) origin datasource name.',
#     'DisplayIndex': 0,
#     'Value': 'Oil Co Demo',
#     'IsReadOnly': True},
#    'totalTags': {'Name': 'Total tags',
#     'Category': 'Equipment Properties',
#     'Description': 'Total number of tags matching the query term.',
#     'DisplayIndex': 0,
#     'Value': 294.0,
#     'IsReadOnly': True}},
#   'DigitalStates': [],
#   'IsMetaTag': False},
#  {'Id': 'LIC002',
#   'Name': 'LIC002',
#   'Description': 'Level Indicator Controller',
#   'UnitOfMeasure': '',
#   'Labels': None,
#   'Properties': {'Is Numeric': {'Name': 'Is Numeric',
#     'Category': 'General',
#     'Description': 'Indicates if the tag contains any numeric values in the CSV data.',
#     'DisplayIndex': 0,
#     'Value': True,
#     'IsReadOnly': True},
#    'Raw Sample Count': {'Name': 'Raw Sample Count',
#     'Category': 'General',
#     'Description': 'The number of raw samples for the tag in the CSV data that was loaded.',
#     'DisplayIndex': 0,
#     'Value': 4320,
#     'IsReadOnly': True},
#    'UTC Earliest Raw Sample Time': {'Name': 'UTC Earliest Raw Sample Time',
#     'Category': 'General',
#     'Description': 'The earliest UTC time stamp in the CSV data that contains values for the tag.',
#     'DisplayIndex': 0,
#     'Value': '2022-01-01T00:00:00Z',
#     'IsReadOnly': True},
#    'UTC Latest Raw Sample Time': {'Name': 'UTC Latest Raw Sample Time',
#     'Category': 'General',
#     'Description': 'The latest UTC time stamp in the CSV data that contains values for the tag.',
#     'DisplayIndex': 0,
#     'Value': None,
#     'IsReadOnly': True},
#    'type': {'Name': 'Tag type',
#     'Category': 'Equipment Properties',
#     'Description': 'Tag (equipment) type.',
#     'DisplayIndex': 0,
#     'Value': 'tag',
#     'IsReadOnly': True},
#    'cats': {'Name': 'Tag cats',
#     'Category': 'Equipment Properties',
#     'Description': 'Tag (equipment) terms.',
#     'DisplayIndex': 0,
#     'Value': 'LIC002,LIC,002,Level,Indicator,Controller,Indicator controller',
#     'IsReadOnly': True},
#    'originDsn': {'Name': 'Tag origin dsn',
#     'Category': 'Equipment Properties',
#     'Description': 'Tag (equipment) origin datasource name.',
#     'DisplayIndex': 0,
#     'Value': 'Oil Co Demo',
#     'IsReadOnly': True},
#    'totalTags': {'Name': 'Total tags',
#     'Category': 'Equipment Properties',
#     'Description': 'Total number of tags matching the query term.',
#     'DisplayIndex': 0,
#     'Value': 294.0,
#     'IsReadOnly': True}},
#   'DigitalStates': [],
#   'IsMetaTag': False},
#  {'Id': 'LIC002_OP',
#   'Name': 'LIC002_OP',
#   'Description': '',
#   'UnitOfMeasure': '',
#   'Labels': None,
#   'Properties': {'Is Numeric': {'Name': 'Is Numeric',
#     'Category': 'General',
#     'Description': 'Indicates if the tag contains any numeric values in the CSV data.',
#     'DisplayIndex': 0,
#     'Value': True,
#     'IsReadOnly': True},
#    'Raw Sample Count': {'Name': 'Raw Sample Count',
#     'Category': 'General',
#     'Description': 'The number of raw samples for the tag in the CSV data that was loaded.',
#     'DisplayIndex': 0,
#     'Value': 4320,
#     'IsReadOnly': True},
#    'UTC Earliest Raw Sample Time': {'Name': 'UTC Earliest Raw Sample Time',
#     'Category': 'General',
#     'Description': 'The earliest UTC time stamp in the CSV data that contains values for the tag.',
#     'DisplayIndex': 0,
#     'Value': '2022-01-01T00:00:00Z',
#     'IsReadOnly': True},
#    'UTC Latest Raw Sample Time': {'Name': 'UTC Latest Raw Sample Time',
#     'Category': 'General',
#     'Description': 'The latest UTC time stamp in the CSV data that contains values for the tag.',
#     'DisplayIndex': 0,
#     'Value': None,
#     'IsReadOnly': True},
#    'type': {'Name': 'Tag type',
#     'Category': 'Equipment Properties',
#     'Description': 'Tag (equipment) type.',
#     'DisplayIndex': 0,
#     'Value': 'tag',
#     'IsReadOnly': True},
#    'cats': {'Name': 'Tag cats',
#     'Category': 'Equipment Properties',
#     'Description': 'Tag (equipment) terms.',
#     'DisplayIndex': 0,
#     'Value': 'LIC002_OP,LIC,002_OP,LIC002,OP,Indicator controller,Level',
#     'IsReadOnly': True},
#    'originDsn': {'Name': 'Tag origin dsn',
#     'Category': 'Equipment Properties',
#     'Description': 'Tag (equipment) origin datasource name.',
#     'DisplayIndex': 0,
#     'Value': 'Oil Co Demo',
#     'IsReadOnly': True},
#    'totalTags': {'Name': 'Total tags',
#     'Category': 'Equipment Properties',
#     'Description': 'Total number of tags matching the query term.',
#     'DisplayIndex': 0,
#     'Value': 294.0,
#     'IsReadOnly': True}},
#   'DigitalStates': [],
#   'IsMetaTag': False},
#  {'Id': 'LIC002_PV',
#   'Name': 'LIC002_PV',
#   'Description': '',
#   'UnitOfMeasure': '',
#   'Labels': None,
#   'Properties': {'Is Numeric': {'Name': 'Is Numeric',
#     'Category': 'General',
#     'Description': 'Indicates if the tag contains any numeric values in the CSV data.',
#     'DisplayIndex': 0,
#     'Value': True,
#     'IsReadOnly': True},
#    'Raw Sample Count': {'Name': 'Raw Sample Count',
#     'Category': 'General',
#     'Description': 'The number of raw samples for the tag in the CSV data that was loaded.',
#     'DisplayIndex': 0,
#     'Value': 4320,
#     'IsReadOnly': True},
#    'UTC Earliest Raw Sample Time': {'Name': 'UTC Earliest Raw Sample Time',
#     'Category': 'General',
#     'Description': 'The earliest UTC time stamp in the CSV data that contains values for the tag.',
#     'DisplayIndex': 0,
#     'Value': '2022-01-01T00:00:00Z',
#     'IsReadOnly': True},
#    'UTC Latest Raw Sample Time': {'Name': 'UTC Latest Raw Sample Time',
#     'Category': 'General',
#     'Description': 'The latest UTC time stamp in the CSV data that contains values for the tag.',
#     'DisplayIndex': 0,
#     'Value': None,
#     'IsReadOnly': True},
#    'type': {'Name': 'Tag type',
#     'Category': 'Equipment Properties',
#     'Description': 'Tag (equipment) type.',
#     'DisplayIndex': 0,
#     'Value': 'tag',
#     'IsReadOnly': True},
#    'cats': {'Name': 'Tag cats',
#     'Category': 'Equipment Properties',
#     'Description': 'Tag (equipment) terms.',
#     'DisplayIndex': 0,
#     'Value': 'LIC002_PV,LIC,002_PV,LIC002,PV,Indicator controller,Level',
#     'IsReadOnly': True},
#    'originDsn': {'Name': 'Tag origin dsn',
#     'Category': 'Equipment Properties',
#     'Description': 'Tag (equipment) origin datasource name.',
#     'DisplayIndex': 0,
#     'Value': 'Oil Co Demo',
#     'IsReadOnly': True},
#    'totalTags': {'Name': 'Total tags',
#     'Category': 'Equipment Properties',
#     'Description': 'Total number of tags matching the query term.',
#     'DisplayIndex': 0,
#     'Value': 294.0,
#     'IsReadOnly': True}},
#   'DigitalStates': [],
#   'IsMetaTag': False},
#  {'Id': 'LIC002_SP',
#   'Name': 'LIC002_SP',
#   'Description': '',
#   'UnitOfMeasure': '',
#   'Labels': None,
#   'Properties': {'Is Numeric': {'Name': 'Is Numeric',
#     'Category': 'General',
#     'Description': 'Indicates if the tag contains any numeric values in the CSV data.',
#     'DisplayIndex': 0,
#     'Value': True,
#     'IsReadOnly': True},
#    'Raw Sample Count': {'Name': 'Raw Sample Count',
#     'Category': 'General',
#     'Description': 'The number of raw samples for the tag in the CSV data that was loaded.',
#     'DisplayIndex': 0,
#     'Value': 4320,
#     'IsReadOnly': True},
#    'UTC Earliest Raw Sample Time': {'Name': 'UTC Earliest Raw Sample Time',
#     'Category': 'General',
#     'Description': 'The earliest UTC time stamp in the CSV data that contains values for the tag.',
#     'DisplayIndex': 0,
#     'Value': '2022-01-01T00:00:00Z',
#     'IsReadOnly': True},
#    'UTC Latest Raw Sample Time': {'Name': 'UTC Latest Raw Sample Time',
#     'Category': 'General',
#     'Description': 'The latest UTC time stamp in the CSV data that contains values for the tag.',
#     'DisplayIndex': 0,
#     'Value': None,
#     'IsReadOnly': True},
#    'type': {'Name': 'Tag type',
#     'Category': 'Equipment Properties',
#     'Description': 'Tag (equipment) type.',
#     'DisplayIndex': 0,
#     'Value': 'tag',
#     'IsReadOnly': True},
#    'cats': {'Name': 'Tag cats',
#     'Category': 'Equipment Properties',
#     'Description': 'Tag (equipment) terms.',
#     'DisplayIndex': 0,
#     'Value': 'LIC002_SP,LIC,002_SP,LIC002,SP,Indicator controller,Level',
#     'IsReadOnly': True},
#    'originDsn': {'Name': 'Tag origin dsn',
#     'Category': 'Equipment Properties',
#     'Description': 'Tag (equipment) origin datasource name.',
#     'DisplayIndex': 0,
#     'Value': 'Oil Co Demo',
#     'IsReadOnly': True},
#    'totalTags': {'Name': 'Total tags',
#     'Category': 'Equipment Properties',
#     'Description': 'Total number of tags matching the query term.',
#     'DisplayIndex': 0,
#     'Value': 294.0,
#     'IsReadOnly': True}},
#   'DigitalStates': [],
#   'IsMetaTag': False},
#  {'Id': 'LIC003',
#   'Name': 'LIC003',
#   'Description': 'Level Indicator Controller',
#   'UnitOfMeasure': '',
#   'Labels': None,
#   'Properties': {'Is Numeric': {'Name': 'Is Numeric',
#     'Category': 'General',
#     'Description': 'Indicates if the tag contains any numeric values in the CSV data.',
#     'DisplayIndex': 0,
#     'Value': True,
#     'IsReadOnly': True},
#    'Raw Sample Count': {'Name': 'Raw Sample Count',
#     'Category': 'General',
#     'Description': 'The number of raw samples for the tag in the CSV data that was loaded.',
#     'DisplayIndex': 0,
#     'Value': 4320,
#     'IsReadOnly': True},
#    'UTC Earliest Raw Sample Time': {'Name': 'UTC Earliest Raw Sample Time',
#     'Category': 'General',
#     'Description': 'The earliest UTC time stamp in the CSV data that contains values for the tag.',
#     'DisplayIndex': 0,
#     'Value': '2022-01-01T00:00:00Z',
#     'IsReadOnly': True},
#    'UTC Latest Raw Sample Time': {'Name': 'UTC Latest Raw Sample Time',
#     'Category': 'General',
#     'Description': 'The latest UTC time stamp in the CSV data that contains values for the tag.',
#     'DisplayIndex': 0,
#     'Value': None,
#     'IsReadOnly': True},
#    'type': {'Name': 'Tag type',
#     'Category': 'Equipment Properties',
#     'Description': 'Tag (equipment) type.',
#     'DisplayIndex': 0,
#     'Value': 'tag',
#     'IsReadOnly': True},
#    'cats': {'Name': 'Tag cats',
#     'Category': 'Equipment Properties',
#     'Description': 'Tag (equipment) terms.',
#     'DisplayIndex': 0,
#     'Value': 'LIC003,LIC,003,Level,Indicator,Controller,Indicator controller',
#     'IsReadOnly': True},
#    'originDsn': {'Name': 'Tag origin dsn',
#     'Category': 'Equipment Properties',
#     'Description': 'Tag (equipment) origin datasource name.',
#     'DisplayIndex': 0,
#     'Value': 'Oil Co Demo',
#     'IsReadOnly': True},
#    'totalTags': {'Name': 'Total tags',
#     'Category': 'Equipment Properties',
#     'Description': 'Total number of tags matching the query term.',
#     'DisplayIndex': 0,
#     'Value': 294.0,
#     'IsReadOnly': True}},
#   'DigitalStates': [],
#   'IsMetaTag': False},
#  {'Id': 'LIC003_OP',
#   'Name': 'LIC003_OP',
#   'Description': '',
#   'UnitOfMeasure': '',
#   'Labels': None,
#   'Properties': {'Is Numeric': {'Name': 'Is Numeric',
#     'Category': 'General',
#     'Description': 'Indicates if the tag contains any numeric values in the CSV data.',
#     'DisplayIndex': 0,
#     'Value': True,
#     'IsReadOnly': True},
#    'Raw Sample Count': {'Name': 'Raw Sample Count',
#     'Category': 'General',
#     'Description': 'The number of raw samples for the tag in the CSV data that was loaded.',
#     'DisplayIndex': 0,
#     'Value': 4320,
#     'IsReadOnly': True},
#    'UTC Earliest Raw Sample Time': {'Name': 'UTC Earliest Raw Sample Time',
#     'Category': 'General',
#     'Description': 'The earliest UTC time stamp in the CSV data that contains values for the tag.',
#     'DisplayIndex': 0,
#     'Value': '2022-01-01T00:00:00Z',
#     'IsReadOnly': True},
#    'UTC Latest Raw Sample Time': {'Name': 'UTC Latest Raw Sample Time',
#     'Category': 'General',
#     'Description': 'The latest UTC time stamp in the CSV data that contains values for the tag.',
#     'DisplayIndex': 0,
#     'Value': None,
#     'IsReadOnly': True},
#    'type': {'Name': 'Tag type',
#     'Category': 'Equipment Properties',
#     'Description': 'Tag (equipment) type.',
#     'DisplayIndex': 0,
#     'Value': 'tag',
#     'IsReadOnly': True},
#    'cats': {'Name': 'Tag cats',
#     'Category': 'Equipment Properties',
#     'Description': 'Tag (equipment) terms.',
#     'DisplayIndex': 0,
#     'Value': 'LIC003_OP,LIC,003_OP,LIC003,OP,Indicator controller,Level',
#     'IsReadOnly': True},
#    'originDsn': {'Name': 'Tag origin dsn',
#     'Category': 'Equipment Properties',
#     'Description': 'Tag (equipment) origin datasource name.',
#     'DisplayIndex': 0,
#     'Value': 'Oil Co Demo',
#     'IsReadOnly': True},
#    'totalTags': {'Name': 'Total tags',
#     'Category': 'Equipment Properties',
#     'Description': 'Total number of tags matching the query term.',
#     'DisplayIndex': 0,
#     'Value': 294.0,
#     'IsReadOnly': True}},
#   'DigitalStates': [],
#   'IsMetaTag': False},
#  {'Id': 'LIC003_PV',
#   'Name': 'LIC003_PV',
#   'Description': '',
#   'UnitOfMeasure': '',
#   'Labels': None,
#   'Properties': {'Is Numeric': {'Name': 'Is Numeric',
#     'Category': 'General',
#     'Description': 'Indicates if the tag contains any numeric values in the CSV data.',
#     'DisplayIndex': 0,
#     'Value': True,
#     'IsReadOnly': True},
#    'Raw Sample Count': {'Name': 'Raw Sample Count',
#     'Category': 'General',
#     'Description': 'The number of raw samples for the tag in the CSV data that was loaded.',
#     'DisplayIndex': 0,
#     'Value': 4320,
#     'IsReadOnly': True},
#    'UTC Earliest Raw Sample Time': {'Name': 'UTC Earliest Raw Sample Time',
#     'Category': 'General',
#     'Description': 'The earliest UTC time stamp in the CSV data that contains values for the tag.',
#     'DisplayIndex': 0,
#     'Value': '2022-01-01T00:00:00Z',
#     'IsReadOnly': True},
#    'UTC Latest Raw Sample Time': {'Name': 'UTC Latest Raw Sample Time',
#     'Category': 'General',
#     'Description': 'The latest UTC time stamp in the CSV data that contains values for the tag.',
#     'DisplayIndex': 0,
#     'Value': None,
#     'IsReadOnly': True},
#    'type': {'Name': 'Tag type',
#     'Category': 'Equipment Properties',
#     'Description': 'Tag (equipment) type.',
#     'DisplayIndex': 0,
#     'Value': 'tag',
#     'IsReadOnly': True},
#    'cats': {'Name': 'Tag cats',
#     'Category': 'Equipment Properties',
#     'Description': 'Tag (equipment) terms.',
#     'DisplayIndex': 0,
#     'Value': 'LIC003_PV,LIC,003_PV,LIC003,PV,Indicator controller,Level',
#     'IsReadOnly': True},
#    'originDsn': {'Name': 'Tag origin dsn',
#     'Category': 'Equipment Properties',
#     'Description': 'Tag (equipment) origin datasource name.',
#     'DisplayIndex': 0,
#     'Value': 'Oil Co Demo',
#     'IsReadOnly': True},
#    'totalTags': {'Name': 'Total tags',
#     'Category': 'Equipment Properties',
#     'Description': 'Total number of tags matching the query term.',
#     'DisplayIndex': 0,
#     'Value': 294.0,
#     'IsReadOnly': True}},
#   'DigitalStates': [],
#   'IsMetaTag': False},
#  {'Id': 'LIC003_SP',
#   'Name': 'LIC003_SP',
#   'Description': '',
#   'UnitOfMeasure': '',
#   'Labels': None,
#   'Properties': {'Is Numeric': {'Name': 'Is Numeric',
#     'Category': 'General',
#     'Description': 'Indicates if the tag contains any numeric values in the CSV data.',
#     'DisplayIndex': 0,
#     'Value': True,
#     'IsReadOnly': True},
#    'Raw Sample Count': {'Name': 'Raw Sample Count',
#     'Category': 'General',
#     'Description': 'The number of raw samples for the tag in the CSV data that was loaded.',
#     'DisplayIndex': 0,
#     'Value': 4320,
#     'IsReadOnly': True},
#    'UTC Earliest Raw Sample Time': {'Name': 'UTC Earliest Raw Sample Time',
#     'Category': 'General',
#     'Description': 'The earliest UTC time stamp in the CSV data that contains values for the tag.',
#     'DisplayIndex': 0,
#     'Value': '2022-01-01T00:00:00Z',
#     'IsReadOnly': True},
#    'UTC Latest Raw Sample Time': {'Name': 'UTC Latest Raw Sample Time',
#     'Category': 'General',
#     'Description': 'The latest UTC time stamp in the CSV data that contains values for the tag.',
#     'DisplayIndex': 0,
#     'Value': None,
#     'IsReadOnly': True},
#    'type': {'Name': 'Tag type',
#     'Category': 'Equipment Properties',
#     'Description': 'Tag (equipment) type.',
#     'DisplayIndex': 0,
#     'Value': 'tag',
#     'IsReadOnly': True},
#    'cats': {'Name': 'Tag cats',
#     'Category': 'Equipment Properties',
#     'Description': 'Tag (equipment) terms.',
#     'DisplayIndex': 0,
#     'Value': 'LIC003_SP,LIC,003_SP,LIC003,SP,Indicator controller,Level',
#     'IsReadOnly': True},
#    'originDsn': {'Name': 'Tag origin dsn',
#     'Category': 'Equipment Properties',
#     'Description': 'Tag (equipment) origin datasource name.',
#     'DisplayIndex': 0,
#     'Value': 'Oil Co Demo',
#     'IsReadOnly': True},
#    'totalTags': {'Name': 'Total tags',
#     'Category': 'Equipment Properties',
#     'Description': 'Total number of tags matching the query term.',
#     'DisplayIndex': 0,
#     'Value': 294.0,
#     'IsReadOnly': True}},
#   'DigitalStates': [],
#   'IsMetaTag': False},
#  {'Id': 'LIC004',
#   'Name': 'LIC004',
#   'Description': 'Level Indicator Controller',
#   'UnitOfMeasure': '',
#   'Labels': None,
#   'Properties': {'Is Numeric': {'Name': 'Is Numeric',
#     'Category': 'General',
#     'Description': 'Indicates if the tag contains any numeric values in the CSV data.',
#     'DisplayIndex': 0,
#     'Value': True,
#     'IsReadOnly': True},
#    'Raw Sample Count': {'Name': 'Raw Sample Count',
#     'Category': 'General',
#     'Description': 'The number of raw samples for the tag in the CSV data that was loaded.',
#     'DisplayIndex': 0,
#     'Value': 4320,
#     'IsReadOnly': True},
#    'UTC Earliest Raw Sample Time': {'Name': 'UTC Earliest Raw Sample Time',
#     'Category': 'General',
#     'Description': 'The earliest UTC time stamp in the CSV data that contains values for the tag.',
#     'DisplayIndex': 0,
#     'Value': '2022-01-01T00:00:00Z',
#     'IsReadOnly': True},
#    'UTC Latest Raw Sample Time': {'Name': 'UTC Latest Raw Sample Time',
#     'Category': 'General',
#     'Description': 'The latest UTC time stamp in the CSV data that contains values for the tag.',
#     'DisplayIndex': 0,
#     'Value': None,
#     'IsReadOnly': True},
#    'type': {'Name': 'Tag type',
#     'Category': 'Equipment Properties',
#     'Description': 'Tag (equipment) type.',
#     'DisplayIndex': 0,
#     'Value': 'tag',
#     'IsReadOnly': True},
#    'cats': {'Name': 'Tag cats',
#     'Category': 'Equipment Properties',
#     'Description': 'Tag (equipment) terms.',
#     'DisplayIndex': 0,
#     'Value': 'LIC004,LIC,004,Level,Indicator,Controller,Indicator controller',
#     'IsReadOnly': True},
#    'originDsn': {'Name': 'Tag origin dsn',
#     'Category': 'Equipment Properties',
#     'Description': 'Tag (equipment) origin datasource name.',
#     'DisplayIndex': 0,
#     'Value': 'Oil Co Demo',
#     'IsReadOnly': True},
#    'totalTags': {'Name': 'Total tags',
#     'Category': 'Equipment Properties',
#     'Description': 'Total number of tags matching the query term.',
#     'DisplayIndex': 0,
#     'Value': 294.0,
#     'IsReadOnly': True}},
#   'DigitalStates': [],
#   'IsMetaTag': False},
#  {'Id': 'LIC004_OP',
#   'Name': 'LIC004_OP',
#   'Description': '',
#   'UnitOfMeasure': '',
#   'Labels': None,
#   'Properties': {'Is Numeric': {'Name': 'Is Numeric',
#     'Category': 'General',
#     'Description': 'Indicates if the tag contains any numeric values in the CSV data.',
#     'DisplayIndex': 0,
#     'Value': True,
#     'IsReadOnly': True},
#    'Raw Sample Count': {'Name': 'Raw Sample Count',
#     'Category': 'General',
#     'Description': 'The number of raw samples for the tag in the CSV data that was loaded.',
#     'DisplayIndex': 0,
#     'Value': 4320,
#     'IsReadOnly': True},
#    'UTC Earliest Raw Sample Time': {'Name': 'UTC Earliest Raw Sample Time',
#     'Category': 'General',
#     'Description': 'The earliest UTC time stamp in the CSV data that contains values for the tag.',
#     'DisplayIndex': 0,
#     'Value': '2022-01-01T00:00:00Z',
#     'IsReadOnly': True},
#    'UTC Latest Raw Sample Time': {'Name': 'UTC Latest Raw Sample Time',
#     'Category': 'General',
#     'Description': 'The latest UTC time stamp in the CSV data that contains values for the tag.',
#     'DisplayIndex': 0,
#     'Value': None,
#     'IsReadOnly': True},
#    'type': {'Name': 'Tag type',
#     'Category': 'Equipment Properties',
#     'Description': 'Tag (equipment) type.',
#     'DisplayIndex': 0,
#     'Value': 'tag',
#     'IsReadOnly': True},
#    'cats': {'Name': 'Tag cats',
#     'Category': 'Equipment Properties',
#     'Description': 'Tag (equipment) terms.',
#     'DisplayIndex': 0,
#     'Value': 'LIC004_OP,LIC,004_OP,LIC004,OP,Indicator controller,Level',
#     'IsReadOnly': True},
#    'originDsn': {'Name': 'Tag origin dsn',
#     'Category': 'Equipment Properties',
#     'Description': 'Tag (equipment) origin datasource name.',
#     'DisplayIndex': 0,
#     'Value': 'Oil Co Demo',
#     'IsReadOnly': True},
#    'totalTags': {'Name': 'Total tags',
#     'Category': 'Equipment Properties',
#     'Description': 'Total number of tags matching the query term.',
#     'DisplayIndex': 0,
#     'Value': 294.0,
#     'IsReadOnly': True}},
#   'DigitalStates': [],
#   'IsMetaTag': False},
#  {'Id': 'LIC004_PV',
#   'Name': 'LIC004_PV',
#   'Description': '',
#   'UnitOfMeasure': '',
#   'Labels': None,
#   'Properties': {'Is Numeric': {'Name': 'Is Numeric',
#     'Category': 'General',
#     'Description': 'Indicates if the tag contains any numeric values in the CSV data.',
#     'DisplayIndex': 0,
#     'Value': True,
#     'IsReadOnly': True},
#    'Raw Sample Count': {'Name': 'Raw Sample Count',
#     'Category': 'General',
#     'Description': 'The number of raw samples for the tag in the CSV data that was loaded.',
#     'DisplayIndex': 0,
#     'Value': 4320,
#     'IsReadOnly': True},
#    'UTC Earliest Raw Sample Time': {'Name': 'UTC Earliest Raw Sample Time',
#     'Category': 'General',
#     'Description': 'The earliest UTC time stamp in the CSV data that contains values for the tag.',
#     'DisplayIndex': 0,
#     'Value': '2022-01-01T00:00:00Z',
#     'IsReadOnly': True},
#    'UTC Latest Raw Sample Time': {'Name': 'UTC Latest Raw Sample Time',
#     'Category': 'General',
#     'Description': 'The latest UTC time stamp in the CSV data that contains values for the tag.',
#     'DisplayIndex': 0,
#     'Value': None,
#     'IsReadOnly': True},
#    'type': {'Name': 'Tag type',
#     'Category': 'Equipment Properties',
#     'Description': 'Tag (equipment) type.',
#     'DisplayIndex': 0,
#     'Value': 'tag',
#     'IsReadOnly': True},
#    'cats': {'Name': 'Tag cats',
#     'Category': 'Equipment Properties',
#     'Description': 'Tag (equipment) terms.',
#     'DisplayIndex': 0,
#     'Value': 'LIC004_PV,LIC,004_PV,LIC004,PV,Indicator controller,Level',
#     'IsReadOnly': True},
#    'originDsn': {'Name': 'Tag origin dsn',
#     'Category': 'Equipment Properties',
#     'Description': 'Tag (equipment) origin datasource name.',
#     'DisplayIndex': 0,
#     'Value': 'Oil Co Demo',
#     'IsReadOnly': True},
#    'totalTags': {'Name': 'Total tags',
#     'Category': 'Equipment Properties',
#     'Description': 'Total number of tags matching the query term.',
#     'DisplayIndex': 0,
#     'Value': 294.0,
#     'IsReadOnly': True}},
#   'DigitalStates': [],
#   'IsMetaTag': False},
#  {'Id': 'LIC004_SP',
#   'Name': 'LIC004_SP',
#   'Description': '',
#   'UnitOfMeasure': '',
#   'Labels': None,
#   'Properties': {'Is Numeric': {'Name': 'Is Numeric',
#     'Category': 'General',
#     'Description': 'Indicates if the tag contains any numeric values in the CSV data.',
#     'DisplayIndex': 0,
#     'Value': True,
#     'IsReadOnly': True},
#    'Raw Sample Count': {'Name': 'Raw Sample Count',
#     'Category': 'General',
#     'Description': 'The number of raw samples for the tag in the CSV data that was loaded.',
#     'DisplayIndex': 0,
#     'Value': 4320,
#     'IsReadOnly': True},
#    'UTC Earliest Raw Sample Time': {'Name': 'UTC Earliest Raw Sample Time',
#     'Category': 'General',
#     'Description': 'The earliest UTC time stamp in the CSV data that contains values for the tag.',
#     'DisplayIndex': 0,
#     'Value': '2022-01-01T00:00:00Z',
#     'IsReadOnly': True},
#    'UTC Latest Raw Sample Time': {'Name': 'UTC Latest Raw Sample Time',
#     'Category': 'General',
#     'Description': 'The latest UTC time stamp in the CSV data that contains values for the tag.',
#     'DisplayIndex': 0,
#     'Value': None,
#     'IsReadOnly': True},
#    'type': {'Name': 'Tag type',
#     'Category': 'Equipment Properties',
#     'Description': 'Tag (equipment) type.',
#     'DisplayIndex': 0,
#     'Value': 'tag',
#     'IsReadOnly': True},
#    'cats': {'Name': 'Tag cats',
#     'Category': 'Equipment Properties',
#     'Description': 'Tag (equipment) terms.',
#     'DisplayIndex': 0,
#     'Value': 'LIC004_SP,LIC,004_SP,LIC004,SP,Indicator controller,Level',
#     'IsReadOnly': True},
#    'originDsn': {'Name': 'Tag origin dsn',
#     'Category': 'Equipment Properties',
#     'Description': 'Tag (equipment) origin datasource name.',
#     'DisplayIndex': 0,
#     'Value': 'Oil Co Demo',
#     'IsReadOnly': True},
#    'totalTags': {'Name': 'Total tags',
#     'Category': 'Equipment Properties',
#     'Description': 'Total number of tags matching the query term.',
#     'DisplayIndex': 0,
#     'Value': 294.0,
#     'IsReadOnly': True}},
#   'DigitalStates': [],
#   'IsMetaTag': False}]

# %% [markdown]
# ## Getting Data
#
# There are multiple different functions that are used to query datqa sources depending on the type of data you want to get and how it should be processed.
#
# ### Tag Map
#
# All of the data query functions take a `tags` parameter. This parameter is used to specify which tags you want to query (and the data source they exist on).
#
# The tag map should be a dictionary where the data source name is the key and the value is a list of tags on that data source.
#
# For example to query the "hed and "flow" tags on IP Data source and the "Air Scour Blowers_Outlet_PI" and "Antifoam Inj Pump B_PI" tags on IP Data source 2 the `tags` parameter would be:

# %%
tags = {
    "IP Datasource": [
        "head",
        "flow"
    ],
    "IP Datasource 2": [
        "Air Scour Blowers_Outlet_PI",
        "Antifoam Inj Pump B_PI"
    ]
}

# %% [markdown]
# ### Time Stamps
#
# Data core allows you to use absolute or relative time stamps in your data queries.
#
# When making a query the time parameters should be a string in one of these formats.
#
# #### Absolute Time Stamps
#
# Absoulte time stamps are in the ISO 8601 format:

# %%
from datetime import datetime, timezone
datetime.now(timezone.utc).isoformat()
# Out:
# '2025-02-10T14:31:16.603245+00:00'

# %% [markdown]
# #### Relative Time Stamps
#
# Relative timestamps can be used to specify a time from the current time.
#
# The `*` character indicates now and the `-` is used to subtract time from it.
#
# Some examples:
# - `"*"` is now
# - `"*-12h"` is 12 hours ago
# - `"*-10d"` is 10 days ago
# - `"*-1y"` is 1 year ago

# %% [markdown]
# ### Responses
#
# #### Tag Value
#
# All of the get data function return values using the tag value objects that looks like this:
#
# ```python
# {
#     "TagName": "<tag name>",
#     "UtcSampleTime": "<yyyy-MM-ddTHH:mm:ss.fffZ>",
#     "NumericValue": "<some number>",
#     "TextValue": "<some text>",
#     "IsNumeric": true | false,
#     "Status": "Good" | "Bad" | "Uncertain",
#     "Unit": "<some unit>",
#     "Notes": "<optional notes>",
#     "Error": "<optional error message>",
#     "HasError": true | false,
#     "Properties": {
#         "prop1": <some value>,
#         ...
#         "propN": <some value>
#     }
# }
# ```
#
# #### Historical Tag Value
#
# Historical data requests return data in a historical tag values object:
#
# ```python
# {
#     "TagName": "<tag name>",
#     # Display hint when visualizing the data i.e straight line between points or trailing/leading edge
#     "DisplayType": "Unspecified" | "Interpolate" | "TrailingEdge" | "LeadingEdge",
#     "Values": [
#         <DataCoreTagValue>,
#         ...
#         <DataCoreTagValue>
#     ]
# }
# ```
#
# #### Response Dictionary
#
# All responses organise the tag values in a dictionary where the key is the data source name and the value is a nested dictionary. The nested dictionary has the tag name as the key and the tag value object (for snapshot) or historical tag value object as the value.
#
# ```python
# {
#     "data source name 1": {
#         "tag_name_1_1": <DataCoreTagValue or DataCoreHistoricalTagValue>,
#         ...
#         "tag_name_1_N": <DataCoreTagValue or DataCoreHistoricalTagValue>
#     },
#     "data source name N": {
#         "tag_name_N_1": <DataCoreTagValue or DataCoreHistoricalTagValue>,
#         ...
#         "tag_name_N_N": <DataCoreTagValue or DataCoreHistoricalTagValue>
#     }
# }
# ```

# %% [markdown]
# ### Get Plot Data
#
# Plot data should be used when you want to draw a plot.
#
# The way plot data is processed a special type of interploation that ensures that the maximum and minium values are preserved so that you don't lose an peaks.
#
# To query plot data use the `get_plot_data(..)` function.
#
# Parameters:
# - `tags` The tag map of tags you want to quer (see the Tag Map section for more details)
# - `start_time` The start time of the query range (see the Time Stamps section for more details)
# - `end_time` The end time of the query range see the Time Stamps section for more details)
# - `intervals` The number of intervals the time range should be divided into
#
# Returns:
#
# A response dictionary as decscribed in the Responses section, with 2 nested dictionarys of data source name and tag name with a historical tag value object as the value.

# %%
data_core.get_plot_data({dsn: ["Air Scour Blowers_Outlet_PI"]}, "*-10d", "*", 10)
# Out:
# {'FCBB05262EADC0B147746EE6DFB2B3EA5C272C33C2C5E3FE8F473D85529461CA.Oil Co Demo': {'Air Scour Blowers_Outlet_PI': {'TagName': 'Air Scour Blowers_Outlet_PI',
#    'DisplayType': 'Interpolate',
#    'Values': [{'TagName': 'Air Scour Blowers_Outlet_PI',
#      'UtcSampleTime': '2025-01-31T14:31:25.6754254Z',
#      'NumericValue': 0.0004354868897532797,
#      'IsNumeric': True,
#      'TextValue': None,
#      'Status': 'Good',
#      'Unit': '',
#      'Notes': 'Interpolated using samples @ 2025-01-31T14:30:00.000Z and 2025-01-31T14:40:00.000Z.',
#      'Error': None,
#      'HasError': False,
#      'Properties': {}},
#     {'TagName': 'Air Scour Blowers_Outlet_PI',
#      'UtcSampleTime': '2025-01-31T14:40:00Z',
#      'NumericValue': 0.000355644,
#      'IsNumeric': True,
#      'TextValue': None,
#      'Status': 'Good',
#      'Unit': '',
#      'Notes': None,
#      'Error': None,
#      'HasError': False,
#      'Properties': {}},
#     {'TagName': 'Air Scour Blowers_Outlet_PI',
#      'UtcSampleTime': '2025-02-01T00:20:00Z',
#      'NumericValue': 0.00755571,
#      'IsNumeric': True,
#      'TextValue': None,
#      'Status': 'Good',
#      'Unit': '',
#      'Notes': None,
#      'Error': None,
#      'HasError': False,
#      'Properties': {}},
#     {'TagName': 'Air Scour Blowers_Outlet_PI',
#      'UtcSampleTime': '2025-02-01T07:20:00Z',
#      'NumericValue': 0.000104304,
#      'IsNumeric': True,
#      'TextValue': None,
#      'Status': 'Good',
#      'Unit': '',
#      'Notes': None,
#      'Error': None,
#      'HasError': False,
#      'Properties': {}},
#     {'TagName': 'Air Scour Blowers_Outlet_PI',
#      'UtcSampleTime': '2025-02-01T14:30:00Z',
#      'NumericValue': 0.000985118,
#      'IsNumeric': True,
#      'TextValue': None,
#      'Status': 'Good',
#      'Unit': '',
#      'Notes': None,
#      'Error': None,
#      'HasError': False,
#      'Properties': {}},
#     {'TagName': 'Air Scour Blowers_Outlet_PI',
#      'UtcSampleTime': '2025-02-01T14:40:00Z',
#      'NumericValue': 0.000864367,
#      'IsNumeric': True,
#      'TextValue': None,
#      'Status': 'Good',
#      'Unit': '',
#      'Notes': None,
#      'Error': None,
#      'HasError': False,
#      'Properties': {}},
#     {'TagName': 'Air Scour Blowers_Outlet_PI',
#      'UtcSampleTime': '2025-02-01T22:10:00Z',
#      'NumericValue': 0.00010343,
#      'IsNumeric': True,
#      'TextValue': None,
#      'Status': 'Good',
#      'Unit': '',
#      'Notes': None,
#      'Error': None,
#      'HasError': False,
#      'Properties': {}},
#     {'TagName': 'Air Scour Blowers_Outlet_PI',
#      'UtcSampleTime': '2025-02-02T12:10:00Z',
#      'NumericValue': 0.005284563,
#      'IsNumeric': True,
#      'TextValue': None,
#      'Status': 'Good',
#      'Unit': '',
#      'Notes': None,
#      'Error': None,
#      'HasError': False,
#      'Properties': {}},
#     {'TagName': 'Air Scour Blowers_Outlet_PI',
#      'UtcSampleTime': '2025-02-02T14:30:00Z',
#      'NumericValue': 0.001077306,
#      'IsNumeric': True,
#      'TextValue': None,
#      'Status': 'Good',
#      'Unit': '',
#      'Notes': None,
#      'Error': None,
#      'HasError': False,
#      'Properties': {}},
#     {'TagName': 'Air Scour Blowers_Outlet_PI',
#      'UtcSampleTime': '2025-02-02T14:40:00Z',
#      'NumericValue': 0.000815112,
#      'IsNumeric': True,
#      'TextValue': None,
#      'Status': 'Good',
#      'Unit': '',
#      'Notes': None,
#      'Error': None,
#      'HasError': False,
#      'Properties': {}},
#     {'TagName': 'Air Scour Blowers_Outlet_PI',
#      'UtcSampleTime': '2025-02-02T18:10:00Z',
#      'NumericValue': 0.010336699,
#      'IsNumeric': True,
#      'TextValue': None,
#      'Status': 'Good',
#      'Unit': '',
#      'Notes': None,
#      'Error': None,
#      'HasError': False,
#      'Properties': {}},
#     {'TagName': 'Air Scour Blowers_Outlet_PI',
#      'UtcSampleTime': '2025-02-03T10:10:00Z',
#      'NumericValue': -0.000156913,
#      'IsNumeric': True,
#      'TextValue': None,
#      'Status': 'Good',
#      'Unit': '',
#      'Notes': None,
#      'Error': None,
#      'HasError': False,
#      'Properties': {}},
#     {'TagName': 'Air Scour Blowers_Outlet_PI',
#      'UtcSampleTime': '2025-02-03T14:30:00Z',
#      'NumericValue': 0.000220401,
#      'IsNumeric': True,
#      'TextValue': None,
#      'Status': 'Good',
#      'Unit': '',
#      'Notes': None,
#      'Error': None,
#      'HasError': False,
#      'Properties': {}},
#     {'TagName': 'Air Scour Blowers_Outlet_PI',
#      'UtcSampleTime': '2025-02-03T14:40:00Z',
#      'NumericValue': 0.0002292,
#      'IsNumeric': True,
#      'TextValue': None,
#      'Status': 'Good',
#      'Unit': '',
#      'Notes': None,
#      'Error': None,
#      'HasError': False,
#      'Properties': {}},
#     {'TagName': 'Air Scour Blowers_Outlet_PI',
#      'UtcSampleTime': '2025-02-04T01:40:00Z',
#      'NumericValue': -0.000156913,
#      'IsNumeric': True,
#      'TextValue': None,
#      'Status': 'Good',
#      'Unit': '',
#      'Notes': None,
#      'Error': None,
#      'HasError': False,
#      'Properties': {}},
#     {'TagName': 'Air Scour Blowers_Outlet_PI',
#      'UtcSampleTime': '2025-02-04T11:40:00Z',
#      'NumericValue': 0.005735058,
#      'IsNumeric': True,
#      'TextValue': None,
#      'Status': 'Good',
#      'Unit': '',
#      'Notes': None,
#      'Error': None,
#      'HasError': False,
#      'Properties': {}},
#     {'TagName': 'Air Scour Blowers_Outlet_PI',
#      'UtcSampleTime': '2025-02-04T14:30:00Z',
#      'NumericValue': 0.002131878,
#      'IsNumeric': True,
#      'TextValue': None,
#      'Status': 'Good',
#      'Unit': '',
#      'Notes': None,
#      'Error': None,
#      'HasError': False,
#      'Properties': {}},
#     {'TagName': 'Air Scour Blowers_Outlet_PI',
#      'UtcSampleTime': '2025-02-04T14:40:00Z',
#      'NumericValue': 0.001916183,
#      'IsNumeric': True,
#      'TextValue': None,
#      'Status': 'Good',
#      'Unit': '',
#      'Notes': None,
#      'Error': None,
#      'HasError': False,
#      'Properties': {}},
#     {'TagName': 'Air Scour Blowers_Outlet_PI',
#      'UtcSampleTime': '2025-02-04T17:40:00Z',
#      'NumericValue': 0.010336699,
#      'IsNumeric': True,
#      'TextValue': None,
#      'Status': 'Good',
#      'Unit': '',
#      'Notes': None,
#      'Error': None,
#      'HasError': False,
#      'Properties': {}},
#     {'TagName': 'Air Scour Blowers_Outlet_PI',
#      'UtcSampleTime': '2025-02-05T13:40:00Z',
#      'NumericValue': 0.00010343,
#      'IsNumeric': True,
#      'TextValue': None,
#      'Status': 'Good',
#      'Unit': '',
#      'Notes': None,
#      'Error': None,
#      'HasError': False,
#      'Properties': {}},
#     {'TagName': 'Air Scour Blowers_Outlet_PI',
#      'UtcSampleTime': '2025-02-05T14:30:00Z',
#      'NumericValue': 0.000354323,
#      'IsNumeric': True,
#      'TextValue': None,
#      'Status': 'Good',
#      'Unit': '',
#      'Notes': None,
#      'Error': None,
#      'HasError': False,
#      'Properties': {}},
#     {'TagName': 'Air Scour Blowers_Outlet_PI',
#      'UtcSampleTime': '2025-02-05T14:40:00Z',
#      'NumericValue': 0.000383419,
#      'IsNumeric': True,
#      'TextValue': None,
#      'Status': 'Good',
#      'Unit': '',
#      'Notes': None,
#      'Error': None,
#      'HasError': False,
#      'Properties': {}},
#     {'TagName': 'Air Scour Blowers_Outlet_PI',
#      'UtcSampleTime': '2025-02-06T04:30:00Z',
#      'NumericValue': 0.000104304,
#      'IsNumeric': True,
#      'TextValue': None,
#      'Status': 'Good',
#      'Unit': '',
#      'Notes': None,
#      'Error': None,
#      'HasError': False,
#      'Properties': {}},
#     {'TagName': 'Air Scour Blowers_Outlet_PI',
#      'UtcSampleTime': '2025-02-06T11:30:00Z',
#      'NumericValue': 0.00755571,
#      'IsNumeric': True,
#      'TextValue': None,
#      'Status': 'Good',
#      'Unit': '',
#      'Notes': None,
#      'Error': None,
#      'HasError': False,
#      'Properties': {}},
#     {'TagName': 'Air Scour Blowers_Outlet_PI',
#      'UtcSampleTime': '2025-02-06T14:30:00Z',
#      'NumericValue': 0.000292237,
#      'IsNumeric': True,
#      'TextValue': None,
#      'Status': 'Good',
#      'Unit': '',
#      'Notes': None,
#      'Error': None,
#      'HasError': False,
#      'Properties': {}},
#     {'TagName': 'Air Scour Blowers_Outlet_PI',
#      'UtcSampleTime': '2025-02-06T14:40:00Z',
#      'NumericValue': 0.000295508,
#      'IsNumeric': True,
#      'TextValue': None,
#      'Status': 'Good',
#      'Unit': '',
#      'Notes': None,
#      'Error': None,
#      'HasError': False,
#      'Properties': {}},
#     {'TagName': 'Air Scour Blowers_Outlet_PI',
#      'UtcSampleTime': '2025-02-07T05:30:00Z',
#      'NumericValue': 0.003124498,
#      'IsNumeric': True,
#      'TextValue': None,
#      'Status': 'Good',
#      'Unit': '',
#      'Notes': None,
#      'Error': None,
#      'HasError': False,
#      'Properties': {}},
#     {'TagName': 'Air Scour Blowers_Outlet_PI',
#      'UtcSampleTime': '2025-02-07T13:20:00Z',
#      'NumericValue': -0.000173854,
#      'IsNumeric': True,
#      'TextValue': None,
#      'Status': 'Good',
#      'Unit': '',
#      'Notes': None,
#      'Error': None,
#      'HasError': False,
#      'Properties': {}},
#     {'TagName': 'Air Scour Blowers_Outlet_PI',
#      'UtcSampleTime': '2025-02-07T14:30:00Z',
#      'NumericValue': 0.00054787,
#      'IsNumeric': True,
#      'TextValue': None,
#      'Status': 'Good',
#      'Unit': '',
#      'Notes': None,
#      'Error': None,
#      'HasError': False,
#      'Properties': {}},
#     {'TagName': 'Air Scour Blowers_Outlet_PI',
#      'UtcSampleTime': '2025-02-07T14:40:00Z',
#      'NumericValue': 0.000446835,
#      'IsNumeric': True,
#      'TextValue': None,
#      'Status': 'Good',
#      'Unit': '',
#      'Notes': None,
#      'Error': None,
#      'HasError': False,
#      'Properties': {}},
#     {'TagName': 'Air Scour Blowers_Outlet_PI',
#      'UtcSampleTime': '2025-02-08T00:20:00Z',
#      'NumericValue': 0.534860673,
#      'IsNumeric': True,
#      'TextValue': None,
#      'Status': 'Good',
#      'Unit': '',
#      'Notes': None,
#      'Error': None,
#      'HasError': False,
#      'Properties': {}},
#     {'TagName': 'Air Scour Blowers_Outlet_PI',
#      'UtcSampleTime': '2025-02-08T06:20:00Z',
#      'NumericValue': -0.000450287,
#      'IsNumeric': True,
#      'TextValue': None,
#      'Status': 'Good',
#      'Unit': '',
#      'Notes': None,
#      'Error': None,
#      'HasError': False,
#      'Properties': {}},
#     {'TagName': 'Air Scour Blowers_Outlet_PI',
#      'UtcSampleTime': '2025-02-08T14:30:00Z',
#      'NumericValue': 0.000412048,
#      'IsNumeric': True,
#      'TextValue': None,
#      'Status': 'Good',
#      'Unit': '',
#      'Notes': None,
#      'Error': None,
#      'HasError': False,
#      'Properties': {}},
#     {'TagName': 'Air Scour Blowers_Outlet_PI',
#      'UtcSampleTime': '2025-02-08T14:40:00Z',
#      'NumericValue': 0.000462681,
#      'IsNumeric': True,
#      'TextValue': None,
#      'Status': 'Good',
#      'Unit': '',
#      'Notes': None,
#      'Error': None,
#      'HasError': False,
#      'Properties': {}},
#     {'TagName': 'Air Scour Blowers_Outlet_PI',
#      'UtcSampleTime': '2025-02-09T10:10:00Z',
#      'NumericValue': -0.000159253,
#      'IsNumeric': True,
#      'TextValue': None,
#      'Status': 'Good',
#      'Unit': '',
#      'Notes': None,
#      'Error': None,
#      'HasError': False,
#      'Properties': {}},
#     {'TagName': 'Air Scour Blowers_Outlet_PI',
#      'UtcSampleTime': '2025-02-09T12:10:00Z',
#      'NumericValue': 0.003791879,
#      'IsNumeric': True,
#      'TextValue': None,
#      'Status': 'Good',
#      'Unit': '',
#      'Notes': None,
#      'Error': None,
#      'HasError': False,
#      'Properties': {}},
#     {'TagName': 'Air Scour Blowers_Outlet_PI',
#      'UtcSampleTime': '2025-02-09T14:30:00Z',
#      'NumericValue': 0.00081921,
#      'IsNumeric': True,
#      'TextValue': None,
#      'Status': 'Good',
#      'Unit': '',
#      'Notes': None,
#      'Error': None,
#      'HasError': False,
#      'Properties': {}},
#     {'TagName': 'Air Scour Blowers_Outlet_PI',
#      'UtcSampleTime': '2025-02-09T14:40:00Z',
#      'NumericValue': 0.000680749,
#      'IsNumeric': True,
#      'TextValue': None,
#      'Status': 'Good',
#      'Unit': '',
#      'Notes': None,
#      'Error': None,
#      'HasError': False,
#      'Properties': {}},
#     {'TagName': 'Air Scour Blowers_Outlet_PI',
#      'UtcSampleTime': '2025-02-09T18:10:00Z',
#      'NumericValue': 0.003213803,
#      'IsNumeric': True,
#      'TextValue': None,
#      'Status': 'Good',
#      'Unit': '',
#      'Notes': None,
#      'Error': None,
#      'HasError': False,
#      'Properties': {}},
#     {'TagName': 'Air Scour Blowers_Outlet_PI',
#      'UtcSampleTime': '2025-02-09T20:10:00Z',
#      'NumericValue': -0.000483094,
#      'IsNumeric': True,
#      'TextValue': None,
#      'Status': 'Good',
#      'Unit': '',
#      'Notes': None,
#      'Error': None,
#      'HasError': False,
#      'Properties': {}},
#     {'TagName': 'Air Scour Blowers_Outlet_PI',
#      'UtcSampleTime': '2025-02-10T14:30:00Z',
#      'NumericValue': 0.000529686,
#      'IsNumeric': True,
#      'TextValue': None,
#      'Status': 'Good',
#      'Unit': '',
#      'Notes': None,
#      'Error': None,
#      'HasError': False,
#      'Properties': {}},
#     {'TagName': 'Air Scour Blowers_Outlet_PI',
#      'UtcSampleTime': '2025-02-10T14:31:25.6754254Z',
#      'NumericValue': 0.000529686,
#      'IsNumeric': True,
#      'TextValue': None,
#      'Status': 'Good',
#      'Unit': '',
#      'Notes': None,
#      'Error': None,
#      'HasError': False,
#      'Properties': {}}]}}}

# %% [markdown]
# ### Get Processed Data
#
# The get process data function is used to fecth data with a certain function applied. This allows the samples to have a consistent interval.
#
# To query processed data use the `get_processed_data(..)` function.
#
# Parameters:
# - `tags` The tag map of tags you want to quer (see the Tag Map section for more details)
# - `start_time` The start time of the query range (see the Time Stamps section for more details)
# - `end_time` The end time of the query range see the Time Stamps section for more details)
# - `sample_interval` A string representing the length of time each sample should represent, this uses a similar format to the realtive time stamps e.g. `"1d"`, `"1h"` etc.
# - `data_function` The data processing function to use for the query. INTERP/AVG/MIN/MAX
#
# Returns:
#
# A response dictionary as decscribed in the Responses section, with 2 nested dictionarys of data source name and tag name with a historical tag value object as the value.

# %%
data_core.get_processed_data({dsn: ["Air Scour Blowers_Outlet_PI"]}, "*-10d", "*", "1d", "interp")
# Out:
# {'FCBB05262EADC0B147746EE6DFB2B3EA5C272C33C2C5E3FE8F473D85529461CA.Oil Co Demo': {'Air Scour Blowers_Outlet_PI': {'TagName': 'Air Scour Blowers_Outlet_PI',
#    'DisplayType': 'Interpolate',
#    'Values': [{'TagName': 'Air Scour Blowers_Outlet_PI',
#      'UtcSampleTime': '2025-01-31T14:31:25.800376Z',
#      'NumericValue': 0.0004354674926303867,
#      'IsNumeric': True,
#      'TextValue': None,
#      'Status': 'Good',
#      'Unit': '',
#      'Notes': 'Interpolated using samples @ 2025-01-31T14:30:00.000Z and 2025-01-31T14:40:00.000Z.',
#      'Error': None,
#      'HasError': False,
#      'Properties': {}},
#     {'TagName': 'Air Scour Blowers_Outlet_PI',
#      'UtcSampleTime': '2025-02-01T14:31:25.800376Z',
#      'NumericValue': 0.0009678505313293734,
#      'IsNumeric': True,
#      'TextValue': None,
#      'Status': 'Good',
#      'Unit': '',
#      'Notes': 'Interpolated using samples @ 2025-02-01T14:30:00.000Z and 2025-02-01T14:40:00.000Z.',
#      'Error': None,
#      'HasError': False,
#      'Properties': {}},
#     {'TagName': 'Air Scour Blowers_Outlet_PI',
#      'UtcSampleTime': '2025-02-02T14:31:25.800376Z',
#      'NumericValue': 0.00103981209369176,
#      'IsNumeric': True,
#      'TextValue': None,
#      'Status': 'Good',
#      'Unit': '',
#      'Notes': 'Interpolated using samples @ 2025-02-02T14:30:00.000Z and 2025-02-02T14:40:00.000Z.',
#      'Error': None,
#      'HasError': False,
#      'Properties': {}},
#     {'TagName': 'Air Scour Blowers_Outlet_PI',
#      'UtcSampleTime': '2025-02-03T14:31:25.800376Z',
#      'NumericValue': 0.00022165926251404,
#      'IsNumeric': True,
#      'TextValue': None,
#      'Status': 'Good',
#      'Unit': '',
#      'Notes': 'Interpolated using samples @ 2025-02-03T14:30:00.000Z and 2025-02-03T14:40:00.000Z.',
#      'Error': None,
#      'HasError': False,
#      'Properties': {}},
#     {'TagName': 'Air Scour Blowers_Outlet_PI',
#      'UtcSampleTime': '2025-02-04T14:31:25.800376Z',
#      'NumericValue': 0.002101033479831133,
#      'IsNumeric': True,
#      'TextValue': None,
#      'Status': 'Good',
#      'Unit': '',
#      'Notes': 'Interpolated using samples @ 2025-02-04T14:30:00.000Z and 2025-02-04T14:40:00.000Z.',
#      'Error': None,
#      'HasError': False,
#      'Properties': {}},
#     {'TagName': 'Air Scour Blowers_Outlet_PI',
#      'UtcSampleTime': '2025-02-05T14:31:25.800376Z',
#      'NumericValue': 0.00035848374623349334,
#      'IsNumeric': True,
#      'TextValue': None,
#      'Status': 'Good',
#      'Unit': '',
#      'Notes': 'Interpolated using samples @ 2025-02-05T14:30:00.000Z and 2025-02-05T14:40:00.000Z.',
#      'Error': None,
#      'HasError': False,
#      'Properties': {}},
#     {'TagName': 'Air Scour Blowers_Outlet_PI',
#      'UtcSampleTime': '2025-02-06T14:31:25.800376Z',
#      'NumericValue': 0.00029270475504982667,
#      'IsNumeric': True,
#      'TextValue': None,
#      'Status': 'Good',
#      'Unit': '',
#      'Notes': 'Interpolated using samples @ 2025-02-06T14:30:00.000Z and 2025-02-06T14:40:00.000Z.',
#      'Error': None,
#      'HasError': False,
#      'Properties': {}},
#     {'TagName': 'Air Scour Blowers_Outlet_PI',
#      'UtcSampleTime': '2025-02-07T14:31:25.800376Z',
#      'NumericValue': 0.0005334219316847333,
#      'IsNumeric': True,
#      'TextValue': None,
#      'Status': 'Good',
#      'Unit': '',
#      'Notes': 'Interpolated using samples @ 2025-02-07T14:30:00.000Z and 2025-02-07T14:40:00.000Z.',
#      'Error': None,
#      'HasError': False,
#      'Properties': {}},
#     {'TagName': 'Air Scour Blowers_Outlet_PI',
#      'UtcSampleTime': '2025-02-08T14:31:25.800376Z',
#      'NumericValue': 0.0004192885507300133,
#      'IsNumeric': True,
#      'TextValue': None,
#      'Status': 'Good',
#      'Unit': '',
#      'Notes': 'Interpolated using samples @ 2025-02-08T14:30:00.000Z and 2025-02-08T14:40:00.000Z.',
#      'Error': None,
#      'HasError': False,
#      'Properties': {}},
#     {'TagName': 'Air Scour Blowers_Outlet_PI',
#      'UtcSampleTime': '2025-02-09T14:31:25.800376Z',
#      'NumericValue': 0.0007994099902311067,
#      'IsNumeric': True,
#      'TextValue': None,
#      'Status': 'Good',
#      'Unit': '',
#      'Notes': 'Interpolated using samples @ 2025-02-09T14:30:00.000Z and 2025-02-09T14:40:00.000Z.',
#      'Error': None,
#      'HasError': False,
#      'Properties': {}},
#     {'TagName': 'Air Scour Blowers_Outlet_PI',
#      'UtcSampleTime': '2025-02-10T14:31:25.800376Z',
#      'NumericValue': 0.00052957746252436,
#      'IsNumeric': True,
#      'TextValue': None,
#      'Status': 'Good',
#      'Unit': '',
#      'Notes': 'Interpolated using samples @ 2025-02-10T14:30:00.000Z and 2025-02-10T14:40:00.000Z.',
#      'Error': None,
#      'HasError': False,
#      'Properties': {}}]}}}

# %% [markdown]
# ### Get Raw Data
#
# The get raw data function is used to get the raw values of the data in a certain time range, without any kind of data processing. Warning: this can causes extremely large amaounts of data t be returned.
#
# To query raw data use the `get_raw_data(..)` function.
#
# Parameters:
# - `tags` The tag map of tags you want to quer (see the Tag Map section for more details)
# - `start_time` The start time of the query range (see the Time Stamps section for more details)
# - `end_time` The end time of the query range see the Time Stamps section for more details)
# - `point_count` the maximum number of data points to return. 0 will fetch as many as possible.
#
# Returns:
#
# A response dictionary as decscribed in the Responses section, with 2 nested dictionarys of data source name and tag name with a historical tag value object as the value.

# %%
data_core.get_raw_data({dsn: ["Air Scour Blowers_Outlet_PI"]}, "*-10d", "*", 10)
# Out:
# {'FCBB05262EADC0B147746EE6DFB2B3EA5C272C33C2C5E3FE8F473D85529461CA.Oil Co Demo': {'Air Scour Blowers_Outlet_PI': {'TagName': 'Air Scour Blowers_Outlet_PI',
#    'DisplayType': 'TrailingEdge',
#    'Values': [{'TagName': 'Air Scour Blowers_Outlet_PI',
#      'UtcSampleTime': '2025-01-31T14:40:00Z',
#      'NumericValue': 0.000355644,
#      'IsNumeric': True,
#      'TextValue': None,
#      'Status': 'Good',
#      'Unit': '',
#      'Notes': None,
#      'Error': None,
#      'HasError': False,
#      'Properties': {}},
#     {'TagName': 'Air Scour Blowers_Outlet_PI',
#      'UtcSampleTime': '2025-01-31T14:50:00Z',
#      'NumericValue': 0.000262501,
#      'IsNumeric': True,
#      'TextValue': None,
#      'Status': 'Good',
#      'Unit': '',
#      'Notes': None,
#      'Error': None,
#      'HasError': False,
#      'Properties': {}},
#     {'TagName': 'Air Scour Blowers_Outlet_PI',
#      'UtcSampleTime': '2025-01-31T15:00:00Z',
#      'NumericValue': 0.000169358,
#      'IsNumeric': True,
#      'TextValue': None,
#      'Status': 'Good',
#      'Unit': '',
#      'Notes': None,
#      'Error': None,
#      'HasError': False,
#      'Properties': {}},
#     {'TagName': 'Air Scour Blowers_Outlet_PI',
#      'UtcSampleTime': '2025-01-31T15:10:00Z',
#      'NumericValue': 'NaN',
#      'IsNumeric': False,
#      'TextValue': '7.62E-05',
#      'Status': 'Good',
#      'Unit': '',
#      'Notes': None,
#      'Error': None,
#      'HasError': False,
#      'Properties': {}},
#     {'TagName': 'Air Scour Blowers_Outlet_PI',
#      'UtcSampleTime': '2025-01-31T15:20:00Z',
#      'NumericValue': 'NaN',
#      'IsNumeric': False,
#      'TextValue': '-1.69E-05',
#      'Status': 'Good',
#      'Unit': '',
#      'Notes': None,
#      'Error': None,
#      'HasError': False,
#      'Properties': {}},
#     {'TagName': 'Air Scour Blowers_Outlet_PI',
#      'UtcSampleTime': '2025-01-31T15:30:00Z',
#      'NumericValue': 'NaN',
#      'IsNumeric': False,
#      'TextValue': '-4.59E-05',
#      'Status': 'Good',
#      'Unit': '',
#      'Notes': None,
#      'Error': None,
#      'HasError': False,
#      'Properties': {}},
#     {'TagName': 'Air Scour Blowers_Outlet_PI',
#      'UtcSampleTime': '2025-01-31T15:40:00Z',
#      'NumericValue': 'NaN',
#      'IsNumeric': False,
#      'TextValue': '-4.58E-05',
#      'Status': 'Good',
#      'Unit': '',
#      'Notes': None,
#      'Error': None,
#      'HasError': False,
#      'Properties': {}},
#     {'TagName': 'Air Scour Blowers_Outlet_PI',
#      'UtcSampleTime': '2025-01-31T15:50:00Z',
#      'NumericValue': 'NaN',
#      'IsNumeric': False,
#      'TextValue': '-4.58E-05',
#      'Status': 'Good',
#      'Unit': '',
#      'Notes': None,
#      'Error': None,
#      'HasError': False,
#      'Properties': {}},
#     {'TagName': 'Air Scour Blowers_Outlet_PI',
#      'UtcSampleTime': '2025-01-31T16:00:00Z',
#      'NumericValue': 'NaN',
#      'IsNumeric': False,
#      'TextValue': '-4.57E-05',
#      'Status': 'Good',
#      'Unit': '',
#      'Notes': None,
#      'Error': None,
#      'HasError': False,
#      'Properties': {}},
#     {'TagName': 'Air Scour Blowers_Outlet_PI',
#      'UtcSampleTime': '2025-01-31T16:10:00Z',
#      'NumericValue': 'NaN',
#      'IsNumeric': False,
#      'TextValue': '-4.56E-05',
#      'Status': 'Good',
#      'Unit': '',
#      'Notes': None,
#      'Error': None,
#      'HasError': False,
#      'Properties': {}}]}}}

# %% [markdown]
# ### Get Data At Times
#
# The get data at times function allows you to qery data and specify the exact sample times you wuld like to have returned.
#
# To query for specific times use the `get_data_at_times(..)` function.
#
# Parameters:
# - `tags` The tag map of tags you want to quer (see the Tag Map section for more details)
# - `utc_sample_times` A list of UTC sample point to get the data for (in the ISO format)
#
# Returns:
#
# A response dictionary as decscribed in the Responses section, with 2 nested dictionarys of data source name and tag name with a historical tag value object as the value.

# %%
data_core.get_data_at_times({dsn: ["Air Scour Blowers_Outlet_PI"]}, [datetime.now(timezone.utc).isoformat()])
# Out:
# {'FCBB05262EADC0B147746EE6DFB2B3EA5C272C33C2C5E3FE8F473D85529461CA.Oil Co Demo': {'Air Scour Blowers_Outlet_PI': {'TagName': 'Air Scour Blowers_Outlet_PI',
#    'DisplayType': 'TrailingEdge',
#    'Values': [{'TagName': 'Air Scour Blowers_Outlet_PI',
#      'UtcSampleTime': '2025-02-10T14:31:16.978055Z',
#      'NumericValue': 0.000529686,
#      'IsNumeric': True,
#      'TextValue': None,
#      'Status': 'Good',
#      'Unit': '',
#      'Notes': 'Repeated from raw value @ 2025-02-10T14:30:00.000Z',
#      'Error': None,
#      'HasError': False,
#      'Properties': {}}]}}}

# %% [markdown]
# ### Get Snapshot Data
#
# The get the current value of some tags use the `get_snapshot_data(..)` function.
#
# Parameters:
# - `tags` The tag map of tags you want to quer (see the Tag Map section for more details)
#
# Returns:
#
# A response dictionary as decscribed in the Responses section, with 2 nested dictionarys of data source name and tag name with a tag value object as the value.

# %%
data_core.get_snapshot_data({dsn: ["Air Scour Blowers_Outlet_PI"]})
# Out:
# {'FCBB05262EADC0B147746EE6DFB2B3EA5C272C33C2C5E3FE8F473D85529461CA.Oil Co Demo': {'Air Scour Blowers_Outlet_PI': {'TagName': 'Air Scour Blowers_Outlet_PI',
#    'UtcSampleTime': '2025-02-10T14:30:00Z',
#    'NumericValue': 0.000529686,
#    'IsNumeric': True,
#    'TextValue': None,
#    'Status': 'Good',
#    'Unit': '',
#    'Notes': None,
#    'Error': None,
#    'HasError': False,
#    'Properties': {}}}}

# %% [markdown]
# ## Data Frame Utility
#
# The intelligent plant package includes a utility function that converts the response object into a pandas data frame.
#
# **This function assumes that the timestamps of all the returned sample for each tag line up which isn't true for all queries and data functions**
#
# Parmaters:
# - `result` The result object from a data core request
# - `include_dsn` (Optional, default=False) Whether data fram column names should include the data source name in the format `{dsn}.{tag name}`
# - `force_numeric` (Optional, default=False) Whether all result data should be interpretted as numeric. By default each sample will be treated as string or numeric based on it's own `IsNumeric` property.
# - `force_string` (Optional, default=False) Whether all result data should be interpretted as a string. By default each sample will be treated as string or numeric based on it's own `IsNumeric` property.
#
# At most on of `force_numeric` and `force_string` can be true.
#
# Returns a data frame of the same data with tag names as column names and the time stamp as the index.
#
# Data frames can be used by a variety of data analysis and machine learning frameworks , see the other demo notebooks for more information

# %%
import intelligent_plant.utility as utility

# %%
resp = data_core.get_processed_data({dsn: ["Air Scour Blowers_Outlet_PI"]}, "*-30d", "*", "1d", "interp")
df = utility.query_result_to_data_frame(resp)
df
# Out:
#                                     Air Scour Blowers_Outlet_PI
# 2025-01-11 14:31:26.255273800+00:00                     0.00053
# 2025-01-12 14:31:26.255273800+00:00                     0.00013
# 2025-01-13 14:31:26.255273800+00:00                    0.003876
# 2025-01-14 14:31:26.255273800+00:00                    0.000253
# 2025-01-15 14:31:26.255273800+00:00                    0.001885
# 2025-01-16 14:31:26.255273800+00:00                    0.000385
# 2025-01-17 14:31:26.255273800+00:00                    0.000296
# 2025-01-18 14:31:26.255273800+00:00                    0.000432
# 2025-01-19 14:31:26.255273800+00:00                     0.00047
# 2025-01-20 14:31:26.255273800+00:00                    0.000661
# 2025-01-21 14:31:26.255273800+00:00                    0.000529
# 2025-01-22 14:31:26.255273800+00:00                    8.72E-05
# 2025-01-23 14:31:26.255273800+00:00                    0.001612
# 2025-01-24 14:31:26.255273800+00:00                    0.000406
# 2025-01-25 14:31:26.255273800+00:00                    0.000606
# 2025-01-26 14:31:26.255273800+00:00                    7.44E-05
# 2025-01-27 14:31:26.255273800+00:00                    0.000583
# 2025-01-28 14:31:26.255273800+00:00                    0.000102
# 2025-01-29 14:31:26.255273800+00:00                    0.000501
# 2025-01-30 14:31:26.255273800+00:00                      0.0003
# 2025-01-31 14:31:26.255273800+00:00                    0.000435
# 2025-02-01 14:31:26.255273800+00:00                    0.000968
# 2025-02-02 14:31:26.255273800+00:00                     0.00104
# 2025-02-03 14:31:26.255273800+00:00                    0.000222
# 2025-02-04 14:31:26.255273800+00:00                    0.002101
# 2025-02-05 14:31:26.255273800+00:00                    0.000359
# 2025-02-06 14:31:26.255273800+00:00                    0.000293
# 2025-02-07 14:31:26.255273800+00:00                    0.000533
# 2025-02-08 14:31:26.255273800+00:00                    0.000419
# 2025-02-09 14:31:26.255273800+00:00                    0.000799
# 2025-02-10 14:31:26.255273800+00:00                     0.00053
